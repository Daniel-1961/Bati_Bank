# %%
import pandas as pd

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(".."))

# %%
from scripts.eda import *

# %%
data=pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\10Academy Files\\Bati_Bank\\notebooks\\DATA\\data.csv")

# %%
eda=EDA(data)

# %% [markdown]
# the data overview

# %%
eda.overview()
# Out:
# Dataset Overview:
#
# Number of Rows: 95662
# Number of Columns: 16
#
# Column Data Types:
#
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# Missing Values per Column:
#
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# ...

# %% [markdown]
# eda.summary_statistics()           # Summary statistics
# eda.plot_numerical_distribution()  # Plot numerical distributions
# eda.plot_categorical_distribution()# Plot categorical distributions
# eda.correlation_analysis()         # Correlation analysis
# eda.identify_missing_values()      # Visualize missing values
# eda.detect_outliers()

# %% [markdown]
# SUMMARY STATISTICS

# %%
eda.summary_statistics()
# Out:
# Summary Statistics for Numerical Features:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000
#
# Summary Statistics for Categorical Features:
#
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# ...

# %% [markdown]
# Plot numerical distributions

# %%
eda.plot_numerical_distribution()

# %% [markdown]
# Correlation analysis
